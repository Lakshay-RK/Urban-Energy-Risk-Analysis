# %%
# !pip install ipykernel
# Out:
# Requirement already satisfied: ipykernel in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (7.2.0)
# Requirement already satisfied: comm>=0.1.1 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ipykernel) (1.8.20)
# Requirement already satisfied: ipython>=7.23.1 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ipykernel) (9.12.0)
# Requirement already satisfied: jupyter-client>=8.8.0 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ipykernel) (8.8.0)
# Requirement already satisfied: jupyter-core!=6.0.*,>=5.1 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ipykernel) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ipykernel) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging>=22 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ipykernel) (26.1)
# Requirement already satisfied: psutil>=5.7 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ipykernel) (7.2.2)
# Requirement already satisfied: pyzmq>=25 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ipykernel) (27.1.0)
# Requirement already satisfied: tornado>=6.4.1 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ipykernel) (6.5.5)
# Requirement already satisfied: traitlets>=5.4.0 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: colorama>=0.4.4 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ipython>=7.23.1->ipykernel) (0.4.6)
# Requirement already satisfied: decorator>=5.1.0 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ipython>=7.23.1->ipykernel) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ipython>=7.23.1->ipykernel) (3.0.52)
# Requirement already satisfied: pygments>=2.14.0 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ipython>=7.23.1->ipykernel) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: wcwidth in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jedi>=0.18.2->ipython>=7.23.1->ipykernel) (0.8.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jupyter-client>=8.8.0->ipykernel) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jupyter-core!=6.0.*,>=5.1->ipykernel) (4.9.6)
# Requirement already satisfied: six>=1.5 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.8.0->ipykernel) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (3.0.1)
# Requirement already satisfied: pure-eval in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel) (0.2.3)

# %%
# !pip install scikit-learn seaborn matplotlib pandas numpy libpysal esda
# Out:
# Requirement already satisfied: scikit-learn in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (1.8.0)
# Requirement already satisfied: seaborn in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (0.13.2)
# Requirement already satisfied: matplotlib in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (3.10.8)
# Requirement already satisfied: pandas in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (3.0.2)
# Requirement already satisfied: numpy in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (2.4.4)
# Requirement already satisfied: libpysal in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (4.14.1)
# Requirement already satisfied: esda in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (2.9.0)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (26.1)
# Requirement already satisfied: pillow>=8 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pandas) (2026.1)
# Requirement already satisfied: beautifulsoup4>=4.13.0 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from libpysal) (4.14.3)
# Requirement already satisfied: geopandas>=0.14.0 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from libpysal) (1.1.3)
# Requirement already satisfied: jinja2 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from libpysal) (3.1.6)
# Requirement already satisfied: platformdirs>=3.11.0 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from libpysal) (4.9.6)
# Requirement already satisfied: requests>=2.32.0 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from libpysal) (2.33.1)
# Requirement already satisfied: shapely>=2.0 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from libpysal) (2.1.2)
# Requirement already satisfied: soupsieve>=1.6.1 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from beautifulsoup4>=4.13.0->libpysal) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from beautifulsoup4>=4.13.0->libpysal) (4.15.0)
# Requirement already satisfied: pyogrio>=0.7.2 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from geopandas>=0.14.0->libpysal) (0.12.1)
# Requirement already satisfied: pyproj>=3.5.0 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from geopandas>=0.14.0->libpysal) (3.7.2)
# Requirement already satisfied: certifi in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pyogrio>=0.7.2->geopandas>=0.14.0->libpysal) (2026.2.25)
# Requirement already satisfied: six>=1.5 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests>=2.32.0->libpysal) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests>=2.32.0->libpysal) (3.12)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests>=2.32.0->libpysal) (2.6.3)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\bhoom\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jinja2->libpysal) (3.0.3)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

from libpysal.weights import lat2W
from esda.moran import Moran

import warnings
warnings.filterwarnings("ignore")

sns.set_theme(style="whitegrid")

# %%
np.random.seed(42)

GRID_SIZE = 25

x, y = np.indices((GRID_SIZE, GRID_SIZE))

center = (x.mean(), y.mean())
dist = np.sqrt((x - center[0])**2 + (y - center[1])**2)

income = 60000 + dist * 3000 + np.random.normal(0, 4000, x.shape)
building_age = 70 - dist * 5 + np.random.normal(0, 7, x.shape)
density = 1200 + (1/(dist+1))*600 + np.random.normal(0, 60, x.shape)
green = np.maximum(0, 60 - dist*2 + np.random.normal(0, 8, x.shape))
industrial = np.random.uniform(0, 120, x.shape)
temperature = 25 + dist * 0.8 + np.random.normal(0, 1, x.shape)

# %%
risk = (
    building_age * 0.7
    - income * 0.0005
    + density * 0.003
    - green * 0.12
    + industrial * 0.06
    + temperature * 1.2
    + 25
)

energy_risk = (risk + np.random.normal(0, 2, risk.shape)).flatten()

# %%
df = pd.DataFrame({
    "income": income.flatten(),
    "building_age": building_age.flatten(),
    "density": density.flatten(),
    "green": green.flatten(),
    "industrial": industrial.flatten(),
    "temperature": temperature.flatten(),
    "distance": dist.flatten()
})

df.head()
# Out:
#           income  building_age      density      green  industrial  \
# 0  112898.544857    -18.431323  1253.240750  37.224345   97.695082
# 1  108283.404584    -18.321337  1284.736330  22.945015   82.216117
# 2  109452.252208     -8.983005  1116.475860  27.085226   13.251824
# 3  111092.119426     -4.609926  1259.943394  16.532494   34.702494
# 4  102330.001807      5.548315  1312.565082  24.708629   37.176825
#
#    temperature   distance
# 0    38.510476  16.970563
# 1    38.473712  16.278821
# 2    37.065685  15.620499
# 3    36.853940  15.000000
# 4    36.667265  14.422205

# %%
df["income_age"] = df["income"] * df["building_age"]
df["density_green"] = df["density"] / (df["green"] + 1)
df["heat_index"] = df["temperature"] * df["density"]
df["industrial_pressure"] = df["industrial"] * df["density"]
df["socio_index"] = df["income"] / (df["density"] + 1)

df.head()
# Out:
#           income  building_age      density      green  industrial  \
# 0  112898.544857    -18.431323  1253.240750  37.224345   97.695082
# 1  108283.404584    -18.321337  1284.736330  22.945015   82.216117
# 2  109452.252208     -8.983005  1116.475860  27.085226   13.251824
# 3  111092.119426     -4.609926  1259.943394  16.532494   34.702494
# 4  102330.001807      5.548315  1312.565082  24.708629   37.176825
#
#    temperature   distance    income_age  density_green    heat_index  \
# 0    38.510476  16.970563 -2.080870e+06      32.786455  48262.897296
# 1    38.473712  16.278821 -1.983897e+06      53.653604  49428.575596
# 2    37.065685  15.620499 -9.832102e+05      39.753137  41382.942287
# 3    36.853940  15.000000 -5.121264e+05      71.863328  46433.878398
# 4    36.667265  14.422205  5.677591e+05      51.055428  48128.171073
#
#    industrial_pressure  socio_index
# 0        122435.458176    90.013456
# 1        105626.032656    84.218982
# 2         14795.341159    97.945966
# 3         43723.177517    88.102384
# 4         48797.002401    77.902498

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(df)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=5)
X_pca = pca.fit_transform(X_scaled)

# %%
from libpysal.weights import lat2W
from esda.moran import Moran

w = lat2W(GRID_SIZE, GRID_SIZE)
w.transform = 'R'

moran = Moran(energy_risk, w)

print("Moran I:", moran.I)
print("p-value:", moran.p_sim)
# Out:
# Moran I: 0.8244026385268328
# p-value: 0.001

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import numpy as np

X_train, X_test, y_train, y_test = train_test_split(X_scaled, energy_risk, test_size=0.2)

model = RandomForestRegressor()
model.fit(X_train, y_train)

pred = model.predict(X_test)

rmse = np.sqrt(mean_squared_error(y_test, pred))
print("RMSE:", rmse)
# Out:
# RMSE: 2.708506412651761

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=5)
clusters = kmeans.fit_predict(X_pca)

df["Cluster"] = clusters
